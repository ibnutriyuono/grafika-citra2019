# %%
import numpy as np 
import matplotlib.pyplot as plt 
import cv2

# %%
img_raw = cv2.imread('./data/train/ryujin500x500.jpg')

# %%
type(img_raw)
# Out:
# numpy.ndarray

# %%
img_raw.shape
# Out:
# (500, 500, 3)

# %%
plt.imshow(img_raw)

# %%
img_rg = cv2.cvtColor(img_raw, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
